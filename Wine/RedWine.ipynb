# %%
import pandas as pd

# %%
filepath = "/home/pk/Eclipse/eclipse-workspace/Python/Wine/winequality-red.csv"
headers = ["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol","quality"]

# %%
df = pd.read_csv(filepath,names = headers)
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df. describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
import numpy as np

# %%
df.replace("?", np.nan, inplace = True)

# %%
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          False             False        False           False      False
# 1          False             False        False           False      False
# 2          False             False        False           False      False
# 3          False             False        False           False      False
# 4          False             False        False           False      False
#
#    free sulfur dioxide  total sulfur dioxide  density     pH  sulphates  \
# 0                False                 False    False  False      False
# 1                False                 False    False  False      False
# 2                False                 False    False  False      False
# 3                False                 False    False  False      False
# 4                False                 False    False  False      False
#
#    alcohol  quality
# 0    False    False
# 1    False    False
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# fixed acidity
# False    1599
# Name: fixed acidity, dtype: int64
#
# volatile acidity
# False    1599
# Name: volatile acidity, dtype: int64
#
# citric acid
# False    1599
# Name: citric acid, dtype: int64
#
# residual sugar
# False    1599
# Name: residual sugar, dtype: int64
#
# chlorides
# False    1599
# Name: chlorides, dtype: int64
#
# free sulfur dioxide
# False    1599
# Name: free sulfur dioxide, dtype: int64
#
# total sulfur dioxide
# False    1599
# Name: total sulfur dioxide, dtype: int64
#
# density
# False    1599
# Name: density, dtype: int64
#
# pH
# False    1599
# Name: pH, dtype: int64
#
# sulphates
# False    1599
# Name: sulphates, dtype: int64
#
# alcohol
# False    1599
# Name: alcohol, dtype: int64
#
# quality
# False    1599
# Name: quality, dtype: int64

# %%
mean_pH = df['pH'].astype('float').mean()
mean_pH
# Out:
# 3.3111131957473416

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
max(df.columns)
# Out:
# 'volatile acidity'

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
max(df.columns)
# Out:
# 'volatile acidity'

# %%
min(df.columns)
# Out:
# 'alcohol'

# %%
df.columns[0]
# Out:
# 'fixed acidity'

# %%
df.columns[1]
# Out:
# 'volatile acidity'

# %%
binwidth = (max(df['pH'])-min(df['pH']))/4

# %%
bin = np.arange(min(df['pH']), max(df['pH']), binwidth)
bin
# Out:
# array([2.74  , 3.0575, 3.375 , 3.6925])

# %%
bin_pH = bin

# %%
bin_pH
# Out:
# array([2.74  , 3.0575, 3.375 , 3.6925])

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
plt.pyplot.hist(df['pH'])
# Out:
# (array([  2.,  27., 134., 361., 555., 352., 132.,  29.,   3.,   4.]),
#  array([2.74 , 2.867, 2.994, 3.121, 3.248, 3.375, 3.502, 3.629, 3.756,
#         3.883, 4.01 ]),
#  <a list of 10 Patch objects>)

# %%
plt.pyplot.hist(df['quality'])
# Out:
# (array([ 10.,   0.,  53.,   0., 681.,   0., 638.,   0., 199.,  18.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <a list of 10 Patch objects>)

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import seaborn as sns

# %%
sns.regplot(x = "pH", y = "quality", data = df)
pyplot.ylim(0,)
# Out:
# (0, 8.25940892279529)

# %%
sns.regplot(x = "alcohol", y = "quality", data = df)
pyplot.ylim(0,)
# Out:
# (0, 8.25940892279529)

# %%
sns.regplot(x = "pH", y = "quality", data = df)
pyplot.ylim()
# Out:
# (2.7405910772047104, 8.25940892279529)

# %%
sns.regplot(x = "pH", y = "quality", data = df)
pyplot.ylim(0)
# Out:
# (0, 8.25940892279529)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df[['pH', 'alcohol', 'citric acid']].corr()
# Out:
#                    pH   alcohol  citric acid
# pH           1.000000  0.205633    -0.541904
# alcohol      0.205633  1.000000     0.109903
# citric acid -0.541904  0.109903     1.000000

# %%
sns.boxplot(x='residual sugar', y='quality', data=df)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df['alcohol'].value_counts().to_frame()
# Out:
#            alcohol
# 9.500000       139
# 9.400000       103
# 9.800000        78
# 9.200000        72
# 10.500000       67
# ...            ...
# 11.950000        1
# 9.233333         1
# 11.066667        1
# 13.200000        1
# 9.566667         1
#
# [65 rows x 1 columns]

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
from scipy import stats

# %%
for column in df.columns:
    pearson_coeff, p_value = stats.pearsonr(df[column], df['quality'])
    print(column + " coeff: ", pearson_coeff, " and p-value: ", p_value, "\n")
# Out:
# fixed acidity coeff:  0.12405164911322429  and p-value:  6.495635009282964e-07
#
# volatile acidity coeff:  -0.39055778026400717  and p-value:  2.0517148070151443e-59
#
# citric acid coeff:  0.2263725143180414  and p-value:  4.9912952505121016e-20
#
# residual sugar coeff:  0.013731637340066292  and p-value:  0.5832180131585295
#
# chlorides coeff:  -0.1289065599300527  and p-value:  2.3133826540602144e-07
#
# free sulfur dioxide coeff:  -0.050656057244276395  and p-value:  0.042833979508175565
#
# total sulfur dioxide coeff:  -0.18510028892653785  and p-value:  8.62170342366267e-14
#
# density coeff:  -0.1749192277833501  and p-value:  1.8749566520107985e-12
#
# pH coeff:  -0.05773139120538215  and p-value:  0.020962778651490887
#
# sulphates coeff:  0.25139707906926123  and p-value:  1.8020884534539657e-24
#
# alcohol coeff:  0.47616632400113607  and p-value:  2.831476974778582e-91
#
# quality coeff:  1.0  and p-value:  0.0

# %%
import pandas as pd

# %%
df.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X = df[['alcohol']]
Y = df['quality']

# %%
lm.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Yhat = lm.predict(X)
Yhat[0:5]
# Out:
# array([5.26688748, 5.41122419, 5.41122419, 5.41122419, 5.26688748])

# %%
Yhat[:]
# Out:
# array([5.26688748, 5.41122419, 5.41122419, ..., 5.84423431, 5.55556089,
#        5.84423431])

# %%
lm.intercept_
# Out:
# 1.8749748869971508

# %%
lm.coef_
# Out:
# array([0.36084177])

# %%
lst = []
for column in df.columns:
    lst.append(column)
    
lst.remove('quality')

# %%
Z = df[lst]

# %%
lm.fit(Z, df['quality'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.intercept_
# Out:
# 21.965208449451552

# %%
lm.coef_
# Out:
# array([ 2.49905527e-02, -1.08359026e+00, -1.82563948e-01,  1.63312698e-02,
#        -1.87422516e+00,  4.36133331e-03, -3.26457970e-03, -1.78811638e+01,
#        -4.13653144e-01,  9.16334413e-01,  2.76197699e-01])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
width = 10
height = 12
plt.figure(figsize=(width, height))
sns.regplot(x="pH", y="quality", data=df)
plt.ylim(0,)
# Out:
# (0, 8.25313630759843)

# %%
plt.figure(figsize=(width, height))
sns.residplot(df['citric acid'], df['quality'])
plt.show()

# %%
Yhat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['quality'], hist=False, color="b", label="Actual Value")
sns.distplot(Yhat, hist=False, color="g", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Quality')
plt.ylabel('Proportion of Wine')

plt.show()
plt.close()

# %%
def PlotPolly(model,independent_variable,dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable,dependent_variabble,'.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Quality ~ Length')
    ax = plt.gca()
    ax.set_fc((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Quality of Wine')

    plt.show()
    plt.close()
    
print("done")
# Out:
# done

# %%
f = np.polyfit(df['pH'], df['quality'], 3)
p = np.poly1d(f)
print(p)
# Out:
#        3         2
# 2.612 x - 26.31 x + 87.81 x - 91.45

# %%
PlotPolly(p,df['alcohol'],df['quality'], 'alcohol')

# %%
np.polyfit(df['alcohol'], df['quality'], 3)
# Out:
# array([-3.02068815e-02,  9.92966457e-01, -1.04284204e+01,  4.06376571e+01])

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr = PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)

# %%
Z_pr=pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (1599, 11)

# %%
Z_pr.shape
# Out:
# (1599, 78)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input=[('scale',StandardScaler()),('polynomial', PolynomialFeatures(include_bias=False)),('model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(memory=None,
#      steps=[('scale', StandardScaler(copy=True, with_mean=True, with_std=True)), ('polynomial', PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)), ('model', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])

# %%
pipe.fit(Z,Y)
# Out:
# Pipeline(memory=None,
#      steps=[('scale', StandardScaler(copy=True, with_mean=True, with_std=True)), ('polynomial', PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)), ('model', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([5.1775106 , 5.09367414, 5.27094359, 5.50436208])

# %%
lm.fit(Z, Y)
lm.score(Z, Y)
# Out:
# 0.36055170303868855

# %%
Yhat=lm.predict(Z)
Yhat[0:4]
# Out:
# array([5.03285045, 5.13787975, 5.20989474, 5.69385794])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(df['quality'], Yhat)
# Out:
# 0.4167671672214078

# %%
lm.fit(Z, df['quality'])
lm.score(Z, df['quality'])
# Out:
# 0.36055170303868855

# %%
Y_predict_multifit = lm.predict(Z)

# %%
mean_squared_error(df['quality'], Y_predict_multifit)
# Out:
# 0.4167671672214078

# %%
from sklearn.metrics import r2_score

# %%
r_squared = r2_score(Y, p(X))
r_squared
# Out:
# -1846631.82302906

# %%
mean_squared_error(df['quality'], p(X))
# Out:
# 1203562.4056067453

# %%
new_input=np.arange(1,100,1).reshape(-1,1)

# %%
lm.fit(X, Y)
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
yhat=lm.predict(new_input)
yhat[0:5]
# Out:
# array([2.23581665, 2.59665842, 2.95750018, 3.31834195, 3.67918371])

# %%
plt.plot(new_input,yhat)
plt.show()

# %%
def DistributionPlot(RedFunction,BlueFunction,RedName,BlueName,Title ):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Quality')
    plt.ylabel('Proportion of Wine')

    plt.show()
    plt.close()

# %%
def PollyPlot(xtrain,xtest,y_train,y_test,lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(),xtest.values.max()])

    xmin=min([xtrain.values.min(),xtest.values.min()])

    x=np.arange(xmin,xmax,0.1)


    plt.plot(xtrain,y_train,'ro',label='Training Data')
    plt.plot(xtest,y_test,'go',label='Test Data')
    plt.plot(x,lr.predict(poly_transform.fit_transform(x.reshape(-1,1))),label='Predicted Function')
    plt.ylim([-10000,60000])
    plt.ylabel('Quality')
    plt.legend()

# %%
y_data=df['quality']

# %%
x_data=df.drop('quality',axis=1)

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.20, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 320
# number of training samples: 1279

# %%
lre=LinearRegression()

# %%
lre.fit(x_train[['pH']],y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lre.score(x_test[['pH']],y_test)
# Out:
# -0.004156765673851259

# %%
lre.score(x_train[['pH']],y_train)
# Out:
# 0.0028931223264286876

# %%
from sklearn.model_selection import cross_val_score
print("done")
# Out:
# done

# %%
Rcross=cross_val_score(lre,x_data[['pH']], y_data,cv=4)

# %%
Rcross
# Out:
# array([-0.03613165, -0.01769027, -0.18175075, -0.02500664])

# %%
print("The mean of the folds are", Rcross.mean(),"and the standard deviation is" ,Rcross.std())
# Out:
# The mean of the folds are -0.06514482849555425 and the standard deviation is 0.06764191345811882

# %%
-1*cross_val_score(lre,x_data[['pH']], y_data,cv=4,scoring='neg_mean_squared_error')
# Out:
# array([0.57440549, 0.61712738, 0.84128836, 0.64942004])

# %%
from sklearn.model_selection import cross_val_predict

# %%
yhat=cross_val_predict(lre,x_data[['pH']], y_data,cv=4)
yhat[0:5]
# Out:
# array([5.61270396, 5.70749845, 5.68915113, 5.71973   , 5.61270396])

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
lr=LinearRegression()
lr.fit(x_train[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']],y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
yhat_train=lr.predict(x_train[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']])
yhat_train[0:5]
# Out:
# array([5.27091129, 5.72219324, 6.97194285, 5.03428538, 5.27052337])

# %%
yhat_test=lr.predict(x_test[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']])
yhat_test[0:5]
# Out:
# array([5.53665503, 5.3757028 , 6.09994909, 5.7271783 , 6.68879378])

# %%
Title='Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution '
DistributionPlot(y_train,yhat_train,"Actual Values (Train)","Predicted Values (Train)",Title)

# %%
Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",Title)

# %%
from sklearn.preprocessing import PolynomialFeatures
print("done")
# Out:
# done

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.45, random_state=0)
print("done")
# Out:
# done

# %%
pr=PolynomialFeatures(degree=5)
x_train_pr=pr.fit_transform(x_train[['alcohol']])
x_test_pr=pr.fit_transform(x_test[['alcohol']])
pr
# Out:
# PolynomialFeatures(degree=5, include_bias=True, interaction_only=False)

# %%
poly=LinearRegression()
poly.fit(x_train_pr,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
yhat=poly.predict(x_test_pr )
yhat[0:5]
# Out:
# array([5.83098882, 5.29916346, 6.19719942, 5.44898497, 5.64028722])

# %%
print("Predicted values:", yhat[0:4])
print("True values:",y_test[0:4].values)
# Out:
# Predicted values: [5.83098882 5.29916346 6.19719942 5.44898497]
# True values: [6 5 7 6]

# %%
PollyPlot(x_train[['alcohol']],x_test[['alcohol']],y_train,y_test,poly,pr)

# %%
poly.score(x_train_pr, y_train)
# Out:
# 0.24933479684302873

# %%
poly.score(x_test_pr, y_test)
# Out:
# 0.19844457969654516

# %%
Rsqu_test=[]

order=[1,2,3,4]
for n in order:
    pr=PolynomialFeatures(degree=n)
    
    x_train_pr=pr.fit_transform(x_train[['alcohol']])
    
    x_test_pr=pr.fit_transform(x_test[['alcohol']])    
    
    lr.fit(x_train_pr,y_train)
    
    Rsqu_test.append(lr.score(x_test_pr,y_test))

plt.plot(order,Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
plt.text(3, 0.75, 'Maximum R^2 ')
# Out:
# Text(3, 0.75, 'Maximum R^2 ')

# %%
def f(order,test_data):
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=test_data, random_state=0)
    pr=PolynomialFeatures(degree=order)
    x_train_pr=pr.fit_transform(x_train[['alcohol']])
    x_test_pr=pr.fit_transform(x_test[['alcohol']])
    poly=LinearRegression()
    poly.fit(x_train_pr,y_train)
    PollyPlot(x_train[['alcohol']],x_test[['alcohol']],y_train,y_test,poly,pr)

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
interact(f, order=(0,6,1),test_data=(0.05,0.95,0.05))
# Out:
# interactive(children=(IntSlider(value=3, description='order', max=6), FloatSlider(value=0.45, description='tes…
# <function __main__.f(order, test_data)>

# %%
pr=PolynomialFeatures(degree=2)
x_train_pr=pr.fit_transform(x_train[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']])
x_test_pr=pr.fit_transform(x_test[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']])

# %%
from sklearn.linear_model import Ridge

# %%
RigeModel=Ridge(alpha=0.1)

# %%
RigeModel.fit(x_train_pr,y_train)
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
yhat=RigeModel.predict(x_test_pr)

# %%
print('predicted:', yhat[0:4])
print('test set :', y_test[0:4].values)
# Out:
# predicted: [5.38402175 5.10892863 6.81377696 5.17518938]
# test set : [6 5 7 6]

# %%
Rsqu_test=[]
Rsqu_train=[]
dummy1=[]
ALFA=5000*np.array(range(0,10000))
for alfa in ALFA:
    RigeModel=Ridge(alpha=alfa) 
    RigeModel.fit(x_train_pr,y_train)
    Rsqu_test.append(RigeModel.score(x_test_pr,y_test))
    Rsqu_train.append(RigeModel.score(x_train_pr,y_train))
    print(alfa)
# Out:
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# 35000
# 40000
# 45000
# 50000
# 55000
# 60000
# 65000
# 70000
# 75000
# 80000
# 85000
# 90000
# 95000
# 100000
# 105000
# 110000
# 115000
# 120000
# 125000
# 130000
# 135000
# 140000
# 145000
# 150000
# 155000
# 160000
# 165000
# 170000
# 175000
# 180000
# 185000
# 190000
# 195000
# 200000
# 205000
# 210000
# 215000
# 220000
# 225000
# 230000
# 235000
# 240000
# 245000
# 250000
# 255000
# 260000
# 265000
# 270000
# 275000
# 280000
# 285000
# 290000
# 295000
# 300000
# 305000
# 310000
# 315000
# 320000
# 325000
# 330000
# 335000
# 340000
# 345000
# 350000
# 355000
# 360000
# 365000
# 370000
# 375000
# 380000
# 385000
# 390000
# 395000
# 400000
# 405000
# 410000
# 415000
# 420000
# 425000
# 430000
# 435000
# 440000
# 445000
# 450000
# 455000
# 460000
# 465000
# 470000
# 475000
# 480000
# 485000
# 490000
# 495000
# 500000
# 505000
# 510000
# 515000
# 520000
# 525000
# 530000
# 535000
# 540000
# 545000
# 550000
# 555000
# 560000
# ...

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))

plt.plot(ALFA,Rsqu_test,label='validation data  ')
plt.plot(ALFA,Rsqu_train,'r',label='training Data ')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.legend()

# %%
from sklearn.model_selection import GridSearchCV
print("done")
# Out:
# done

# %%
parameters1= [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000]}]
parameters1
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

# %%
RR=Ridge()
RR
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
Grid1 = GridSearchCV(RR, parameters1,cv=4)

# %%
Grid1.fit(x_data[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']],y_data)
# Out:
# GridSearchCV(cv=4, error_score='raise',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
BestRR=Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
BestRR.score(x_test[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']],y_test)
# Out:
# 0.3253133754280889
